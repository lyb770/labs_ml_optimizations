# %% [markdown]
# # Hello world
# ## Optimization algorithms: demo

# %% [markdown]
# <em><b>Note</b>: This is just a demo of optimization techniques - not related to any real-life problem.</em>
#
# Imagine the world of strings where the environment demands that the strings are very fit. An unfit string cannot survive.
#
# How do we define the fitness of a string? The environment demands that the string should be as similar as possible to the target string $s$=''Hello, world''. The closer the string is to ''Hello, world'', the better its chances of survival.
#
# <b> The problem:</b> given a set of random strings of length len($s$) over alphabet $\sigma=\{32 \ldots 122\}$, produce the string which best matches the environment, i.e. with a minimum fitness score.
#
# Let <em>Weighted Hamming Distance</em> between two strings $x$ and $y$ (both of length $n$) be defined as:<br>
# $WH(x,y) = \sum_{i=0}^{n} abs(x[i] - y[i])$
#
# $WH(x,y)$ estimates how far is $x$ from $y$. The lower $WH(x,y)$, the closer string $x$ approaches the target string $y$.<br>
# In the space of $\sigma^n$ of all possible strings, we are looking for a global minimum - the string $m$ such that $WH(m,s)$ is minimized. <br>
#
# If we compute $WH(x,s)$ for an arbitrary string $x$, we say that we evaluate the <em>fitness</em> of $x$ with respect to the target string $s$. This is our <em>fitness function</em>.

# %% [markdown]
# ## 1. Preparation

# %%
# flag which can be turned on/off to print the steps of each optimization
print_steps = True

# %% [markdown]
# ### 1.1. String fitness function

# %%
s = 'Hello, world'
n = len(s)

# fitness function - weighted hamming distance
string_fitness = lambda x: sum([abs(ord(x[i])- ord(s[i])) for i in range(n)])

# %% [markdown]
# ### 1.2. Generating initial random strings

# %%
import random

alphabet = range(32,123)

def get_random_string(n, sigma):    
    t = [chr(random.choice(sigma)) for i in range(n)]
    return ''.join(t)

# build initial population of many random strings of target length n
def get_rand_population(population_size, n, sigma):
    population=[]
    for i in range(0,population_size):
        individual_str = get_random_string(n, sigma)
        population.append(individual_str)
    return population

# test
print(get_random_string(len(s), alphabet))
print(get_rand_population(3, len(s), alphabet ))
# Out:
# h aOXkCs>3;M
# ['mpIUSP*<e9m+', "tase,'\\U4t*w", 'k P3."8[z56Z']

# %% [markdown]
# ## 2. Random optimize
#
# The simplest possible idea is to try a vaste amount of random solutions and select the one with the best fitness score. Let's see how close we can get to the target $s$=''Hello, world'' with this approach.
#
# After all, isn't evolution just a lottery? ''Physics makes rules, evolution rolls the dice'' ( Charles Cockell. "The Equations of Life").

# %%
def random_optimize(population, fitness_function):
    best_score = None
    best_solution = None
    for i in range(len(population)):
        # Calculate fitness 
        score = fitness_function(population[i])

        # Compare it to the best one so far
        if best_score == None or score < best_score:
            best_score = score
            best_solution = population[i]
            if print_steps:
                print(best_solution, " -> score:", best_score)
            
    return (best_score, best_solution, len(population))


# Now the test
string_population = get_rand_population(204800, len(s), alphabet)

best_score, best_sol, iterations = random_optimize (string_population, string_fitness)
# Out:
# y``O_B"9 y1-  -> score: 397
# QAc*0-p/duuV  -> score: 373
# Ig@_@3V\]24A  -> score: 368
# swj$"5$*obEk  -> score: 364
# BU[s@*itiI^X  -> score: 244
# _`gdc!DkcRTw  -> score: 199
# -VwndJ$rx^ky  -> score: 156
# #dlztEKttqxd  -> score: 146
# $Gjsd4.olp]k  -> score: 143
# OemWt+QZmdf]  -> score: 142
# \owYw+'seZnq  -> score: 129
# 8uopj2?qqxoq  -> score: 111
# UYtcx'1shiqn  -> score: 108
# Cgwjv2/wcNef  -> score: 105

# %%
print()
print("*************Rand optimize**************")
print("trials:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))
# Out:
# *************Rand optimize**************
# trials:204800, best solution:'Cgwjv2/wcNef', best score:105

# %% [markdown]
# Randomly trying different solutions is very inefficient because the probability of getting anything close to perfect Hello, world is $(\frac{1}{90})^{12}$. No matter how many random guesses you try – the fitness of the resulting string is very low (the distance from the target remains high).

# %% [markdown]
# ## 3. Hill climbing
#
# We did not advance far with the random optimization. This happens because each time we come up with some solution and evaluate its fitness - we discard it and try another one - not related to the previous.
#
# The idea behing the <em>hill climbing</em> optimization is to start at a random point in space (choose one random string), and try to move from this point into a direction of better fitness. We will generate a set of neighbors for a randomly selected string, and see if any of these neighbors improve the overall fitness score of the string.
#
# We continue moving into the direction of this better solution, until there is no more improvement.
#
# <img src="images/hillclimbing.jpg" style="height:200px;">
#
#
# The algorithm may produce an optimal solution, but it may also get stuck at the local minimum.
# <img src="images/localmin.jpg" style="height:200px;">

# %%
def hillclimb_optimize(start_point, fitness_function):
    sol = start_point
    score = fitness_function(sol)
    iterations = 0
    
    # Main loop
    while 1:
        iterations += 1
        
        current_best_score = score
        # Create  neighboring solutions
        neighbors=[]

        for j in range(len(s)):
            # Change character at position j one up or one down
            if ord(sol[j])>32:
                neighbors.append(sol[0:j]+chr(ord(sol[j])-1)+sol[j+1:])
            if ord(sol[j])<122:
                neighbors.append(sol[0:j]+chr(ord(sol[j])+1)+sol[j+1:])
        
        for n_str in neighbors:
            n_score = fitness_function(n_str)
            if n_score < score:
                score = n_score
                sol = n_str
                if print_steps:
                    print(sol, " -> score:", score)      
        
        # If there's no improvement, then we've reached the bottom of the hill
        if score == current_best_score:
            break        
        
        if score == 0:
            break        
        
    return (score, sol, iterations)

# Now the test

rand_str = get_random_string(len(s), alphabet)
best_score, best_sol, iterations = hillclimb_optimize(rand_str, string_fitness)
# Out:
# N?Hj>iPh'*t&  -> score: 469
# M?Hj>iPh'*t&  -> score: 468
# L?Hj>iPh'*t&  -> score: 467
# K?Hj>iPh'*t&  -> score: 466
# J?Hj>iPh'*t&  -> score: 465
# I?Hj>iPh'*t&  -> score: 464
# H?Hj>iPh'*t&  -> score: 463
# H@Hj>iPh'*t&  -> score: 462
# HAHj>iPh'*t&  -> score: 461
# HBHj>iPh'*t&  -> score: 460
# HCHj>iPh'*t&  -> score: 459
# HDHj>iPh'*t&  -> score: 458
# HEHj>iPh'*t&  -> score: 457
# HFHj>iPh'*t&  -> score: 456
# HGHj>iPh'*t&  -> score: 455
# HHHj>iPh'*t&  -> score: 454
# HIHj>iPh'*t&  -> score: 453
# HJHj>iPh'*t&  -> score: 452
# HKHj>iPh'*t&  -> score: 451
# HLHj>iPh'*t&  -> score: 450
# HMHj>iPh'*t&  -> score: 449
# HNHj>iPh'*t&  -> score: 448
# HOHj>iPh'*t&  -> score: 447
# HPHj>iPh'*t&  -> score: 446
# HQHj>iPh'*t&  -> score: 445
# HRHj>iPh'*t&  -> score: 444
# HSHj>iPh'*t&  -> score: 443
# HTHj>iPh'*t&  -> score: 442
# HUHj>iPh'*t&  -> score: 441
# HVHj>iPh'*t&  -> score: 440
# HWHj>iPh'*t&  -> score: 439
# HXHj>iPh'*t&  -> score: 438
# HYHj>iPh'*t&  -> score: 437
# HZHj>iPh'*t&  -> score: 436
# H[Hj>iPh'*t&  -> score: 435
# H\Hj>iPh'*t&  -> score: 434
# H]Hj>iPh'*t&  -> score: 433
# H^Hj>iPh'*t&  -> score: 432
# H_Hj>iPh'*t&  -> score: 431
# H`Hj>iPh'*t&  -> score: 430
# HaHj>iPh'*t&  -> score: 429
# HbHj>iPh'*t&  -> score: 428
# HcHj>iPh'*t&  -> score: 427
# HdHj>iPh'*t&  -> score: 426
# HeHj>iPh'*t&  -> score: 425
# HeIj>iPh'*t&  -> score: 424
# HeJj>iPh'*t&  -> score: 423
# HeKj>iPh'*t&  -> score: 422
# HeLj>iPh'*t&  -> score: 421
# HeMj>iPh'*t&  -> score: 420
# HeNj>iPh'*t&  -> score: 419
# HeOj>iPh'*t&  -> score: 418
# HePj>iPh'*t&  -> score: 417
# HeQj>iPh'*t&  -> score: 416
# HeRj>iPh'*t&  -> score: 415
# HeSj>iPh'*t&  -> score: 414
# HeTj>iPh'*t&  -> score: 413
# HeUj>iPh'*t&  -> score: 412
# HeVj>iPh'*t&  -> score: 411
# HeWj>iPh'*t&  -> score: 410
# HeXj>iPh'*t&  -> score: 409
# HeYj>iPh'*t&  -> score: 408
# HeZj>iPh'*t&  -> score: 407
# He[j>iPh'*t&  -> score: 406
# He\j>iPh'*t&  -> score: 405
# He]j>iPh'*t&  -> score: 404
# He^j>iPh'*t&  -> score: 403
# He_j>iPh'*t&  -> score: 402
# He`j>iPh'*t&  -> score: 401
# Heaj>iPh'*t&  -> score: 400
# Hebj>iPh'*t&  -> score: 399
# Hecj>iPh'*t&  -> score: 398
# Hedj>iPh'*t&  -> score: 397
# Heej>iPh'*t&  -> score: 396
# Hefj>iPh'*t&  -> score: 395
# Hegj>iPh'*t&  -> score: 394
# Hehj>iPh'*t&  -> score: 393
# Heij>iPh'*t&  -> score: 392
# Hejj>iPh'*t&  -> score: 391
# Hekj>iPh'*t&  -> score: 390
# Helj>iPh'*t&  -> score: 389
# Helk>iPh'*t&  -> score: 388
# Hell>iPh'*t&  -> score: 387
# Hell?iPh'*t&  -> score: 386
# Hell@iPh'*t&  -> score: 385
# HellAiPh'*t&  -> score: 384
# HellBiPh'*t&  -> score: 383
# HellCiPh'*t&  -> score: 382
# HellDiPh'*t&  -> score: 381
# HellEiPh'*t&  -> score: 380
# HellFiPh'*t&  -> score: 379
# HellGiPh'*t&  -> score: 378
# HellHiPh'*t&  -> score: 377
# HellIiPh'*t&  -> score: 376
# HellJiPh'*t&  -> score: 375
# HellKiPh'*t&  -> score: 374
# HellLiPh'*t&  -> score: 373
# HellMiPh'*t&  -> score: 372
# HellNiPh'*t&  -> score: 371
# HellOiPh'*t&  -> score: 370
# HellPiPh'*t&  -> score: 369
# HellQiPh'*t&  -> score: 368
# HellRiPh'*t&  -> score: 367
# HellSiPh'*t&  -> score: 366
# HellTiPh'*t&  -> score: 365
# HellUiPh'*t&  -> score: 364
# HellViPh'*t&  -> score: 363
# HellWiPh'*t&  -> score: 362
# HellXiPh'*t&  -> score: 361
# HellYiPh'*t&  -> score: 360
# HellZiPh'*t&  -> score: 359
# Hell[iPh'*t&  -> score: 358
# Hell\iPh'*t&  -> score: 357
# Hell]iPh'*t&  -> score: 356
# Hell^iPh'*t&  -> score: 355
# Hell_iPh'*t&  -> score: 354
# Hell`iPh'*t&  -> score: 353
# HellaiPh'*t&  -> score: 352
# HellbiPh'*t&  -> score: 351
# HellciPh'*t&  -> score: 350
# HelldiPh'*t&  -> score: 349
# HelleiPh'*t&  -> score: 348
# HellfiPh'*t&  -> score: 347
# HellgiPh'*t&  -> score: 346
# HellhiPh'*t&  -> score: 345
# HelliiPh'*t&  -> score: 344
# HelljiPh'*t&  -> score: 343
# HellkiPh'*t&  -> score: 342
# HellliPh'*t&  -> score: 341
# HellmiPh'*t&  -> score: 340
# HellniPh'*t&  -> score: 339
# HelloiPh'*t&  -> score: 338
# HellohPh'*t&  -> score: 337
# HellogPh'*t&  -> score: 336
# HellofPh'*t&  -> score: 335
# HelloePh'*t&  -> score: 334
# HellodPh'*t&  -> score: 333
# HellocPh'*t&  -> score: 332
# HellobPh'*t&  -> score: 331
# HelloaPh'*t&  -> score: 330
# Hello`Ph'*t&  -> score: 329
# Hello_Ph'*t&  -> score: 328
# Hello^Ph'*t&  -> score: 327
# Hello]Ph'*t&  -> score: 326
# Hello\Ph'*t&  -> score: 325
# Hello[Ph'*t&  -> score: 324
# HelloZPh'*t&  -> score: 323
# HelloYPh'*t&  -> score: 322
# HelloXPh'*t&  -> score: 321
# HelloWPh'*t&  -> score: 320
# HelloVPh'*t&  -> score: 319
# HelloUPh'*t&  -> score: 318
# HelloTPh'*t&  -> score: 317
# HelloSPh'*t&  -> score: 316
# HelloRPh'*t&  -> score: 315
# HelloQPh'*t&  -> score: 314
# HelloPPh'*t&  -> score: 313
# HelloOPh'*t&  -> score: 312
# HelloNPh'*t&  -> score: 311
# HelloMPh'*t&  -> score: 310
# HelloLPh'*t&  -> score: 309
# HelloKPh'*t&  -> score: 308
# HelloJPh'*t&  -> score: 307
# HelloIPh'*t&  -> score: 306
# HelloHPh'*t&  -> score: 305
# HelloGPh'*t&  -> score: 304
# HelloFPh'*t&  -> score: 303
# HelloEPh'*t&  -> score: 302
# HelloDPh'*t&  -> score: 301
# HelloCPh'*t&  -> score: 300
# HelloBPh'*t&  -> score: 299
# HelloAPh'*t&  -> score: 298
# Hello@Ph'*t&  -> score: 297
# Hello?Ph'*t&  -> score: 296
# Hello>Ph'*t&  -> score: 295
# Hello=Ph'*t&  -> score: 294
# Hello<Ph'*t&  -> score: 293
# Hello;Ph'*t&  -> score: 292
# Hello:Ph'*t&  -> score: 291
# Hello9Ph'*t&  -> score: 290
# Hello8Ph'*t&  -> score: 289
# Hello7Ph'*t&  -> score: 288
# Hello6Ph'*t&  -> score: 287
# Hello5Ph'*t&  -> score: 286
# Hello4Ph'*t&  -> score: 285
# Hello3Ph'*t&  -> score: 284
# Hello2Ph'*t&  -> score: 283
# Hello1Ph'*t&  -> score: 282
# Hello0Ph'*t&  -> score: 281
# Hello/Ph'*t&  -> score: 280
# Hello.Ph'*t&  -> score: 279
# Hello-Ph'*t&  -> score: 278
# Hello,Ph'*t&  -> score: 277
# Hello,Oh'*t&  -> score: 276
# Hello,Nh'*t&  -> score: 275
# Hello,Mh'*t&  -> score: 274
# Hello,Lh'*t&  -> score: 273
# Hello,Kh'*t&  -> score: 272
# Hello,Jh'*t&  -> score: 271
# Hello,Ih'*t&  -> score: 270
# Hello,Hh'*t&  -> score: 269
# Hello,Gh'*t&  -> score: 268
# Hello,Fh'*t&  -> score: 267
# Hello,Eh'*t&  -> score: 266
# Hello,Dh'*t&  -> score: 265
# Hello,Ch'*t&  -> score: 264
# Hello,Bh'*t&  -> score: 263
# Hello,Ah'*t&  -> score: 262
# Hello,@h'*t&  -> score: 261
# Hello,?h'*t&  -> score: 260
# Hello,>h'*t&  -> score: 259
# Hello,=h'*t&  -> score: 258
# Hello,<h'*t&  -> score: 257
# Hello,;h'*t&  -> score: 256
# Hello,:h'*t&  -> score: 255
# Hello,9h'*t&  -> score: 254
# Hello,8h'*t&  -> score: 253
# Hello,7h'*t&  -> score: 252
# Hello,6h'*t&  -> score: 251
# Hello,5h'*t&  -> score: 250
# Hello,4h'*t&  -> score: 249
# Hello,3h'*t&  -> score: 248
# Hello,2h'*t&  -> score: 247
# Hello,1h'*t&  -> score: 246
# Hello,0h'*t&  -> score: 245
# Hello,/h'*t&  -> score: 244
# Hello,.h'*t&  -> score: 243
# Hello,-h'*t&  -> score: 242
# Hello,,h'*t&  -> score: 241
# Hello,+h'*t&  -> score: 240
# Hello,*h'*t&  -> score: 239
# Hello,)h'*t&  -> score: 238
# Hello,(h'*t&  -> score: 237
# Hello,'h'*t&  -> score: 236
# Hello,&h'*t&  -> score: 235
# Hello,%h'*t&  -> score: 234
# Hello,$h'*t&  -> score: 233
# Hello,#h'*t&  -> score: 232
# Hello,"h'*t&  -> score: 231
# Hello,!h'*t&  -> score: 230
# Hello, h'*t&  -> score: 229
# Hello, i'*t&  -> score: 228
# Hello, j'*t&  -> score: 227
# Hello, k'*t&  -> score: 226
# Hello, l'*t&  -> score: 225
# Hello, m'*t&  -> score: 224
# Hello, n'*t&  -> score: 223
# Hello, o'*t&  -> score: 222
# Hello, p'*t&  -> score: 221
# Hello, q'*t&  -> score: 220
# Hello, r'*t&  -> score: 219
# Hello, s'*t&  -> score: 218
# Hello, t'*t&  -> score: 217
# Hello, u'*t&  -> score: 216
# Hello, v'*t&  -> score: 215
# Hello, w'*t&  -> score: 214
# Hello, w(*t&  -> score: 213
# Hello, w)*t&  -> score: 212
# Hello, w**t&  -> score: 211
# Hello, w+*t&  -> score: 210
# Hello, w,*t&  -> score: 209
# Hello, w-*t&  -> score: 208
# Hello, w.*t&  -> score: 207
# Hello, w/*t&  -> score: 206
# Hello, w0*t&  -> score: 205
# Hello, w1*t&  -> score: 204
# Hello, w2*t&  -> score: 203
# Hello, w3*t&  -> score: 202
# Hello, w4*t&  -> score: 201
# Hello, w5*t&  -> score: 200
# Hello, w6*t&  -> score: 199
# Hello, w7*t&  -> score: 198
# Hello, w8*t&  -> score: 197
# Hello, w9*t&  -> score: 196
# Hello, w:*t&  -> score: 195
# Hello, w;*t&  -> score: 194
# Hello, w<*t&  -> score: 193
# Hello, w=*t&  -> score: 192
# Hello, w>*t&  -> score: 191
# Hello, w?*t&  -> score: 190
# Hello, w@*t&  -> score: 189
# Hello, wA*t&  -> score: 188
# Hello, wB*t&  -> score: 187
# Hello, wC*t&  -> score: 186
# Hello, wD*t&  -> score: 185
# Hello, wE*t&  -> score: 184
# Hello, wF*t&  -> score: 183
# Hello, wG*t&  -> score: 182
# Hello, wH*t&  -> score: 181
# Hello, wI*t&  -> score: 180
# Hello, wJ*t&  -> score: 179
# Hello, wK*t&  -> score: 178
# Hello, wL*t&  -> score: 177
# Hello, wM*t&  -> score: 176
# Hello, wN*t&  -> score: 175
# Hello, wO*t&  -> score: 174
# Hello, wP*t&  -> score: 173
# Hello, wQ*t&  -> score: 172
# Hello, wR*t&  -> score: 171
# Hello, wS*t&  -> score: 170
# Hello, wT*t&  -> score: 169
# Hello, wU*t&  -> score: 168
# Hello, wV*t&  -> score: 167
# Hello, wW*t&  -> score: 166
# Hello, wX*t&  -> score: 165
# Hello, wY*t&  -> score: 164
# Hello, wZ*t&  -> score: 163
# Hello, w[*t&  -> score: 162
# Hello, w\*t&  -> score: 161
# Hello, w]*t&  -> score: 160
# Hello, w^*t&  -> score: 159
# Hello, w_*t&  -> score: 158
# Hello, w`*t&  -> score: 157
# Hello, wa*t&  -> score: 156
# Hello, wb*t&  -> score: 155
# Hello, wc*t&  -> score: 154
# Hello, wd*t&  -> score: 153
# Hello, we*t&  -> score: 152
# Hello, wf*t&  -> score: 151
# Hello, wg*t&  -> score: 150
# Hello, wh*t&  -> score: 149
# Hello, wi*t&  -> score: 148
# Hello, wj*t&  -> score: 147
# Hello, wk*t&  -> score: 146
# Hello, wl*t&  -> score: 145
# Hello, wm*t&  -> score: 144
# Hello, wn*t&  -> score: 143
# Hello, wo*t&  -> score: 142
# Hello, wo+t&  -> score: 141
# Hello, wo,t&  -> score: 140
# Hello, wo-t&  -> score: 139
# Hello, wo.t&  -> score: 138
# Hello, wo/t&  -> score: 137
# Hello, wo0t&  -> score: 136
# Hello, wo1t&  -> score: 135
# Hello, wo2t&  -> score: 134
# Hello, wo3t&  -> score: 133
# Hello, wo4t&  -> score: 132
# Hello, wo5t&  -> score: 131
# Hello, wo6t&  -> score: 130
# Hello, wo7t&  -> score: 129
# Hello, wo8t&  -> score: 128
# Hello, wo9t&  -> score: 127
# Hello, wo:t&  -> score: 126
# Hello, wo;t&  -> score: 125
# Hello, wo<t&  -> score: 124
# Hello, wo=t&  -> score: 123
# Hello, wo>t&  -> score: 122
# Hello, wo?t&  -> score: 121
# Hello, wo@t&  -> score: 120
# Hello, woAt&  -> score: 119
# Hello, woBt&  -> score: 118
# Hello, woCt&  -> score: 117
# Hello, woDt&  -> score: 116
# Hello, woEt&  -> score: 115
# Hello, woFt&  -> score: 114
# Hello, woGt&  -> score: 113
# Hello, woHt&  -> score: 112
# Hello, woIt&  -> score: 111
# Hello, woJt&  -> score: 110
# Hello, woKt&  -> score: 109
# Hello, woLt&  -> score: 108
# Hello, woMt&  -> score: 107
# Hello, woNt&  -> score: 106
# Hello, woOt&  -> score: 105
# Hello, woPt&  -> score: 104
# Hello, woQt&  -> score: 103
# Hello, woRt&  -> score: 102
# Hello, woSt&  -> score: 101
# Hello, woTt&  -> score: 100
# Hello, woUt&  -> score: 99
# Hello, woVt&  -> score: 98
# Hello, woWt&  -> score: 97
# Hello, woXt&  -> score: 96
# Hello, woYt&  -> score: 95
# Hello, woZt&  -> score: 94
# Hello, wo[t&  -> score: 93
# Hello, wo\t&  -> score: 92
# Hello, wo]t&  -> score: 91
# Hello, wo^t&  -> score: 90
# Hello, wo_t&  -> score: 89
# Hello, wo`t&  -> score: 88
# Hello, woat&  -> score: 87
# Hello, wobt&  -> score: 86
# Hello, woct&  -> score: 85
# Hello, wodt&  -> score: 84
# Hello, woet&  -> score: 83
# Hello, woft&  -> score: 82
# Hello, wogt&  -> score: 81
# Hello, woht&  -> score: 80
# Hello, woit&  -> score: 79
# Hello, wojt&  -> score: 78
# Hello, wokt&  -> score: 77
# Hello, wolt&  -> score: 76
# Hello, womt&  -> score: 75
# Hello, wont&  -> score: 74
# Hello, woot&  -> score: 73
# Hello, wopt&  -> score: 72
# Hello, woqt&  -> score: 71
# Hello, wort&  -> score: 70
# Hello, wors&  -> score: 69
# Hello, worr&  -> score: 68
# Hello, worq&  -> score: 67
# Hello, worp&  -> score: 66
# Hello, woro&  -> score: 65
# Hello, worn&  -> score: 64
# Hello, worm&  -> score: 63
# Hello, worl&  -> score: 62
# Hello, worl'  -> score: 61
# Hello, worl(  -> score: 60
# Hello, worl)  -> score: 59
# Hello, worl*  -> score: 58
# Hello, worl+  -> score: 57
# Hello, worl,  -> score: 56
# Hello, worl-  -> score: 55
# Hello, worl.  -> score: 54
# Hello, worl/  -> score: 53
# Hello, worl0  -> score: 52
# Hello, worl1  -> score: 51
# Hello, worl2  -> score: 50
# Hello, worl3  -> score: 49
# Hello, worl4  -> score: 48
# Hello, worl5  -> score: 47
# Hello, worl6  -> score: 46
# Hello, worl7  -> score: 45
# Hello, worl8  -> score: 44
# Hello, worl9  -> score: 43
# Hello, worl:  -> score: 42
# Hello, worl;  -> score: 41
# Hello, worl<  -> score: 40
# Hello, worl=  -> score: 39
# Hello, worl>  -> score: 38
# Hello, worl?  -> score: 37
# Hello, worl@  -> score: 36
# Hello, worlA  -> score: 35
# Hello, worlB  -> score: 34
# Hello, worlC  -> score: 33
# Hello, worlD  -> score: 32
# Hello, worlE  -> score: 31
# Hello, worlF  -> score: 30
# Hello, worlG  -> score: 29
# Hello, worlH  -> score: 28
# Hello, worlI  -> score: 27
# Hello, worlJ  -> score: 26
# Hello, worlK  -> score: 25
# Hello, worlL  -> score: 24
# Hello, worlM  -> score: 23
# Hello, worlN  -> score: 22
# Hello, worlO  -> score: 21
# Hello, worlP  -> score: 20
# Hello, worlQ  -> score: 19
# Hello, worlR  -> score: 18
# Hello, worlS  -> score: 17
# Hello, worlT  -> score: 16
# Hello, worlU  -> score: 15
# Hello, worlV  -> score: 14
# Hello, worlW  -> score: 13
# Hello, worlX  -> score: 12
# Hello, worlY  -> score: 11
# Hello, worlZ  -> score: 10
# Hello, worl[  -> score: 9
# Hello, worl\  -> score: 8
# Hello, worl]  -> score: 7
# Hello, worl^  -> score: 6
# Hello, worl_  -> score: 5
# Hello, worl`  -> score: 4
# Hello, worla  -> score: 3
# Hello, worlb  -> score: 2
# Hello, worlc  -> score: 1
# Hello, world  -> score: 0

# %%
print()
print("*************Hill climbing****************")
print("steps:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))
# Out:
# *************Hill climbing****************
# steps:470, best solution:'Hello, world', best score:0

# %% [markdown]
# ## 3. Simulated annealing
# The idea of the <em>simulated annealing</em> is borrowed from physics. In metalurgical annealing we heat a metal (alloy) to a very high temperature, the crystal bonds break, and the atoms diffuse more freely. If we cool it slowly, the atoms tend to form more regular crystals producing an alloy with the low termodynamics energy.
#
# <img style="height:250px;float:right;padding:4px;" src="images/sim_annealing.jpg" >
#
# In the <em>simulated annealing</em> algorithm we set the initial temperature very high, and then we generate a single random neighbor of the current solution. The fitness of this neihgbor can be better or worse that that of the current solution. When the temperature is high, the probability of selecting worse solution is higher. This allows to better explore the search space and get out of the local minimum. The temperature gradually decreases, and so at the end we do not accept worse solutions.
#
# The criterion of accepting ''bad'' solutions:
#
# $p=e^{\frac{-\Delta F}{T}}>R(0,1)$
#
# where $T$ is the current temperature, $R(0,1)$ is a random number between $0$ and $1$, and $\Delta F$ is the difference between the fitness score of new solution and the old solution.
#
# Since the temperature $T$ (the willingness to accept a worse solution) starts very high,
# the exponent will be close to 0, and $p$ will almost be 1. As the temperature decreases, the difference between the new fitness score and the old one becomes more important - a bigger difference leads to a lower probability, so the
# algorithm will not accept solutions which do not improve fitness - converging to a local minimum after exploring a large global search space.

# %%
import math

def annealing_optimize(start_sol, fitness_function, T=10000.0, cool=0.95, step=1):    
    sol = start_sol
    iterations = 0
    
    # Graduate cooling
    while T > 0.01: 
        score = fitness_function(sol)
        
        # Choose one of spots randomly
        i = random.randint(0, len(sol) - 1)

        # Choose rand direction to change the character at position i
        dir = random.randint(-step, step)

        change = ord(sol[i]) + dir
        # out of domain
        if change > 122 or change < 32:
            continue
    
        iterations += 1
        
        # Create a new solution with one of the characters changed
        new_sol = sol[:i] + chr(change) + sol[i+1:]

        # Calculate the new cost
        new_score = fitness_function(new_sol)        

        # Does it make the probability cutoff?
        p = pow(math.e, -(new_score - score) / T)
        
        if new_score < score or p > random.random() :
            sol = new_sol
            score = new_score
            if print_steps:
                print(sol, "-> score:", score)       
        
        if score == 0:
            break
            
        # Decrease the temperature
        T = T * cool
    
    return (score, sol, iterations)

# now test
rand_str = get_random_string(len(s), alphabet)
best_score, best_sol, iterations = annealing_optimize(rand_str, string_fitness,
                                          T=204800.0, cool=0.999, step=1)

# %%
print()
print("*************Simulated annealing***************")
print("steps:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))

# %% [markdown]
# ## 4. Genetic algorithm
#
# This optimization technique is inspired by the theory of evolution. The algorithm starts with a population of random individuals, and selects the ones with the best fitness score (elite). It continues to the next generation with this group. In order to enrich the genetic pool in the current generation, the algorithm adds random mutations and crossover to the elite group. After predefined number of generations, the algorithm returns the top-fit individual.

# %% [markdown]
# ### 4.1. Mutation and crossover

# %%
# Mutation Operation
def string_mutation(individual):
    i = random.randint(0, len(individual) - 1)

    # mutation changes character at random position to any valid character   
    rchar = chr(random.randint(32, 122))

    individual = individual[0:i] + rchar + individual[(i + 1):]
    return individual


# Mate operation (crossover)
def string_crossover (s1, s2):
    # find the point of crossover
    i = random.randint (0, len(s1)-1)
    return s1[:i]+s2[i:]

# %% [markdown]
# ### 4.2. Algorithm
#
# Initial population - a list of random strings

# %%
def genetic_optimize(population, fitness_function,
                     mutation_function, mate_function,
                     mutation_probability, elite_ratio,
                     maxiterations):

    # How many winners to consider from each generation?
    original_population_size = len(population)
    top_elite = int(elite_ratio * original_population_size)

    # Main loop
    iterations = 0
    for i in range(maxiterations):
        iterations += 1
        individual_scores = [(fitness_function(v), v) for v in population]
        individual_scores.sort()
        ranked_individuals = [v for (s, v) in individual_scores]

        # Start with the pure winners
        population = ranked_individuals[0:top_elite]

        # Add mutated and bred forms of the winners
        while len(population) < original_population_size:
            if random.random() < mutation_probability:
                # Mutation
                c = random.randint(0, top_elite)
                population.append(mutation_function(ranked_individuals[c]))
            else:
                # Crossover
                c1 = random.randint(0, top_elite)
                c2 = random.randint(0, top_elite)
                population.append(mate_function(ranked_individuals[c1], ranked_individuals[c2]))

        # Print current best score
        if print_steps:
            print(individual_scores[0][1]," -> score:", individual_scores[0][0])

        if individual_scores[0][0] == 0:
            return (individual_scores[0][0],individual_scores[0][1], iterations)

    # returns the best solution
    return (individual_scores[0][0], individual_scores[0][1], iterations)



string_population = get_rand_population(2048, len(s), alphabet)
best_score, best_sol, iterations  = genetic_optimize(string_population, string_fitness,
                                string_mutation, string_crossover,
                                mutation_probability=0.25, elite_ratio=0.1,
                                maxiterations=100)
print()
print("*****************GENETIC ALGORITHM ***************")
print("generations:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))

# %% [markdown]
# ### This is the end of the ''Hello, world'' demo.
# Copyright &copy; 2022 Marina Barsky
